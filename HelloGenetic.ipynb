# %%
import random
import math

class HelloGenetic:
  def __init__(self, params):
    self.ALL_CHARACTERS = list("qwertyuiopasdfghjklñzxcvbnmQWERTYUIOPASDFGHJKLÑZXCVBNM. ,!¡")
    self.HELLO_WORLD = list("Hello, world!")
    self.params = params
    self.specimen = [None] * self.params["generation_size"]

    self.create_initial_population()

  def create_initial_population(self):
    self.specimen = list(map(lambda _: random.sample(self.ALL_CHARACTERS, len(self.HELLO_WORLD)), self.specimen))

  def fitness(self, specimen):
    return sum(1 for expected, actual in zip(self.HELLO_WORLD, specimen) if expected == actual)/len(self.HELLO_WORLD)

  def is_converged(self):
    if any(self.fitness(specimen) >= self.params["fit_threshold"] for specimen in self.specimen):
      return True

    return False

  def get_fit(self):
    evaluations = self.fitness_all()

    max_evaluation = max(evaluations)

    max_index = evaluations.index(max_evaluation)

    return self.specimen[max_index], max_evaluation

  def fitness_all(self):
    return list(map(self.fitness, self.specimen))

  def select_specimen(self, specimen_evaluations):
    specimen_and_evaluations = list(zip(self.specimen, specimen_evaluations))

    specimen_and_evaluations.sort(key=lambda e: e[1], reverse = True) 

    n_top = int(math.ceil(len(self.specimen) * params["select_top"]))

    return list(map(lambda s: s[0], specimen_and_evaluations[:n_top]))
  
  def mutate(self, specimen):
    n_digits = int(params["mutation_percentage"] * (len(specimen) - 1))

    digit_indexes = random.sample(list(range(len(specimen))), n_digits)

    mutated = specimen[:]

    for idx in digit_indexes:
      mutated[idx] = random.choice(self.ALL_CHARACTERS)

    return mutated

  def generate_children(self, selected_specimen):  
    mutated_specimen = [None] * len(self.specimen)

    for i in range(len(mutated_specimen)):
      mutated_specimen[i] = self.mutate(random.choice(selected_specimen))

    return mutated_specimen

  def run(self):
    generation_number = 1

    while generation_number <= self.params["max_generations"] and not self.is_converged():
      top_generation = self.get_fit()
      top_str = "".join(top_generation[0])
      
      print(f"Generation #{generation_number}:\t{top_str}\t{top_generation[1]}")

      specimen_evaluations = self.fitness_all()
      selected_specimen = self.select_specimen(specimen_evaluations)
      
      self.specimen = self.generate_children(selected_specimen)
      
      generation_number += 1
    
    return self.get_fit()

# %%
params = {
    "mutation_percentage": 0.1,
    "select_top": 0.05,
    "generation_size": 20,
    "fit_threshold": 1,
    "max_generations": 1000
}

hello = HelloGenetic(params)
fit  = hello.run()

print("".join(fit[0]), fit[1])
# Out:
# Generation #1:	ÑCtQovVhzpbY!	0.15384615384615385
# Generation #2:	GCtQovVhzpbY!	0.15384615384615385
# Generation #3:	GCtQo,VhzpbY!	0.23076923076923078
# Generation #4:	GCtQo,MhzpbY!	0.23076923076923078
# Generation #5:	GCtQo,MUzpbY!	0.23076923076923078
# Generation #6:	bCtQo,MUzpbY!	0.23076923076923078
# Generation #7:	bCtDo,MUzpbY!	0.23076923076923078
# Generation #8:	bCtDo,MUzpbI!	0.23076923076923078
# Generation #9:	betDo,MUzpbI!	0.3076923076923077
# Generation #10:	betDo,MUzpbd!	0.38461538461538464
# Generation #11:	betDo,MUzpHd!	0.38461538461538464
# Generation #12:	betDo,MUYpHd!	0.38461538461538464
# Generation #13:	beADo,MUYpHd!	0.38461538461538464
# Generation #14:	reADo,MUYpHd!	0.38461538461538464
# Generation #15:	reAIo,MUYpHd!	0.38461538461538464
# Generation #16:	PeAIo,MUYpHd!	0.38461538461538464
# Generation #17:	PeAVo,MUYpHd!	0.38461538461538464
# Generation #18:	PeAVo,MUrpHd!	0.38461538461538464
# Generation #19:	PeAVo,MUrpHd!	0.38461538461538464
# Generation #20:	VeAVo,MUrpHd!	0.38461538461538464
# Generation #21:	VeAVo,MUrhHd!	0.38461538461538464
# Generation #22:	VeAVo,MUrhdd!	0.38461538461538464
# Generation #23:	PeAVo,MUrhdd!	0.38461538461538464
# Generation #24:	PeAVo,Mwrhdd!	0.46153846153846156
# Generation #25:	PeAVo,MwHhdd!	0.46153846153846156
# Generation #26:	PeADo,MwHhdd!	0.46153846153846156
# Generation #27:	PeADo,MwHhod!	0.46153846153846156
# Generation #28:	PeADo,MwHhQd!	0.46153846153846156
# Generation #29:	PeADo,MwHhQd!	0.46153846153846156
# Generation #30:	PeAqo,MwHhQd!	0.46153846153846156
# Generation #31:	PeAqo,IwHhQd!	0.46153846153846156
# Generation #32:	PeAqo,IwHFQd!	0.46153846153846156
# Generation #33:	OeAqo,IwHFQd!	0.46153846153846156
# Generation #34:	OeAqo,IwYFQd!	0.46153846153846156
# Generation #35:	OeAqo,IwYFyd!	0.46153846153846156
# Generation #36:	OeAqo,IwYbyd!	0.46153846153846156
# Generation #37:	OeAmo,IwYbyd!	0.46153846153846156
# Generation #38:	OeAmo,NwYbyd!	0.46153846153846156
# Generation #39:	veAmo,NwYbyd!	0.46153846153846156
# Generation #40:	veAmo,NwKbyd!	0.46153846153846156
# Generation #41:	veAmo,NwKvyd!	0.46153846153846156
# Generation #42:	HeAmo,NwKvyd!	0.5384615384615384
# Generation #43:	Helmo,NwKvyd!	0.6153846153846154
# Generation #44:	Helmo,NwWvyd!	0.6153846153846154
# Generation #45:	Helmo,NwWiyd!	0.6153846153846154
# Generation #46:	HelJo,NwWiyd!	0.6153846153846154
# Generation #47:	HelJo,NwWryd!	0.6923076923076923
# Generation #48:	HelJo, wWryd!	0.7692307692307693
# Generation #49:	HelJo, wWrwd!	0.7692307692307693
# Generation #50:	HelJo, wzrwd!	0.7692307692307693
# Generation #51:	HelJo, wOrwd!	0.7692307692307693
# Generation #52:	HelJo, wOrld!	0.8461538461538461
# Generation #53:	HelJo, wErld!	0.8461538461538461
# Generation #54:	HelJo, wsrld!	0.8461538461538461
# Generation #55:	HelJo, wbrld!	0.8461538461538461
# Generation #56:	HelJo, w!rld!	0.8461538461538461
# Generation #57:	HelJo, wVrld!	0.8461538461538461
# Generation #58:	HelJo, wjrld!	0.8461538461538461
# Generation #59:	Helwo, wjrld!	0.8461538461538461
# Generation #60:	Helwo, wJrld!	0.8461538461538461
# Generation #61:	HelXo, wJrld!	0.8461538461538461
# Generation #62:	HelXo, wTrld!	0.8461538461538461
# Generation #63:	HelLo, wTrld!	0.8461538461538461
# Generation #64:	HelUo, wTrld!	0.8461538461538461
# Generation #65:	Helpo, wTrld!	0.8461538461538461
# Generation #66:	Heldo, wTrld!	0.8461538461538461
# Generation #67:	Heldo, w¡rld!	0.8461538461538461
# Generation #68:	Heldo, w¡rld!	0.8461538461538461
# Generation #69:	HelVo, w¡rld!	0.8461538461538461
# Generation #70:	HelVox w¡rld!	0.7692307692307693
# Generation #71:	Helhox w¡rld!	0.7692307692307693
# Generation #72:	Helrox w¡rld!	0.7692307692307693
# Generation #73:	Helrox w¡rld!	0.7692307692307693
# Generation #74:	HelroY w¡rld!	0.7692307692307693
# Generation #75:	Helroj w¡rld!	0.7692307692307693
# Generation #76:	HelroA w¡rld!	0.7692307692307693
# Generation #77:	HelroO w¡rld!	0.7692307692307693
# Generation #78:	HelroU w¡rld!	0.7692307692307693
# Generation #79:	HelroU wYrld!	0.7692307692307693
# Generation #80:	HelCoU wYrld!	0.7692307692307693
# Generation #81:	HelCoU wfrld!	0.7692307692307693
# Generation #82:	HelPoU wfrld!	0.7692307692307693
# Generation #83:	HelzoU wfrld!	0.7692307692307693
# Generation #84:	HelñoU wfrld!	0.7692307692307693
# Generation #85:	HelñoU wirld!	0.7692307692307693
# Generation #86:	Helños wirld!	0.7692307692307693
# Generation #87:	HelDos wirld!	0.7692307692307693
# Generation #88:	HelDos wÑrld!	0.7692307692307693
# Generation #89:	HelDos wSrld!	0.7692307692307693
# Generation #90:	HelDos wqrld!	0.7692307692307693
# Generation #91:	HelDo, wqrld!	0.8461538461538461
# Generation #92:	HelDo, wQrld!	0.8461538461538461
# Generation #93:	HelDo, wQrld!	0.8461538461538461
# Generation #94:	HelDo, wNrld!	0.8461538461538461
# Generation #95:	HelSo, wNrld!	0.8461538461538461
# Generation #96:	HelSo, wcrld!	0.8461538461538461
# Generation #97:	HelSo, wDrld!	0.8461538461538461
# Generation #98:	Helro, wDrld!	0.8461538461538461
# Generation #99:	Helrb, wDrld!	0.7692307692307693
# Generation #100:	Helrb, wYrld!	0.7692307692307693
# Generation #101:	Helrb, wYrld!	0.7692307692307693
# Generation #102:	HelVb, wYrld!	0.7692307692307693
# Generation #103:	HelVb, wVrld!	0.7692307692307693
# Generation #104:	HelVb, wGrld!	0.7692307692307693
# Generation #105:	HelVy, wGrld!	0.7692307692307693
# Generation #106:	HelVy, wnrld!	0.7692307692307693
# Generation #107:	HelOy, wnrld!	0.7692307692307693
# Generation #108:	HelOy, w.rld!	0.7692307692307693
# Generation #109:	HelOs, w.rld!	0.7692307692307693
# Generation #110:	HelHs, w.rld!	0.7692307692307693
# Generation #111:	HelGs, w.rld!	0.7692307692307693
# Generation #112:	HelG!, w.rld!	0.7692307692307693
# Generation #113:	HelGb, w.rld!	0.7692307692307693
# Generation #114:	HelGb, wUrld!	0.7692307692307693
# Generation #115:	HelG., wUrld!	0.7692307692307693
# Generation #116:	HelG., wzrld!	0.7692307692307693
# Generation #117:	HelG., wmrld!	0.7692307692307693
# Generation #118:	HelGs, wmrld!	0.7692307692307693
# Generation #119:	HelGR, wmrld!	0.7692307692307693
# Generation #120:	HelaR, wmrld!	0.7692307692307693
# Generation #121:	HelxR, wmrld!	0.7692307692307693
# Generation #122:	HelHR, wmrld!	0.7692307692307693
# Generation #123:	HelHQ, wmrld!	0.7692307692307693
# Generation #124:	HelHm, wmrld!	0.7692307692307693
# Generation #125:	HelHm, wmrld!	0.7692307692307693
# Generation #126:	Hellm, wmrld!	0.8461538461538461
# Generation #127:	Hellm, wqrld!	0.8461538461538461
# Generation #128:	Hellm, wbrld!	0.8461538461538461
# Generation #129:	Hellm, wVrld!	0.8461538461538461
# Generation #130:	Hello, wVrld!	0.9230769230769231
# Generation #131:	Hello, w rld!	0.9230769230769231
# Generation #132:	Hello, wLrld!	0.9230769230769231
# Generation #133:	Hello, w.rld!	0.9230769230769231
# Generation #134:	Hello, wÑrld!	0.9230769230769231
# Generation #135:	Hello, wNrld!	0.9230769230769231
# Generation #136:	Hello, wNrld!	0.9230769230769231
# Generation #137:	Hello, wcrld!	0.9230769230769231
# Generation #138:	Hello, wcrld!	0.9230769230769231
# Generation #139:	Hello, wnrld!	0.9230769230769231
# Generation #140:	Hello, wÑrld!	0.9230769230769231
# Generation #141:	Hello, wMrld!	0.9230769230769231
# Generation #142:	HelMo, wMrld!	0.8461538461538461
# Generation #143:	HelMo, wtrld!	0.8461538461538461
# Generation #144:	HelMo, w rld!	0.8461538461538461
# Generation #145:	Helpo, w rld!	0.8461538461538461
# Generation #146:	Helpo, w¡rld!	0.8461538461538461
# Generation #147:	Helpo, wsrld!	0.8461538461538461
# Generation #148:	Helpo, w¡rld!	0.8461538461538461
# Generation #149:	HelIo, w¡rld!	0.8461538461538461
# Generation #150:	HelIo, wBrld!	0.8461538461538461
# Generation #151:	HelIo, wLrld!	0.8461538461538461
# Generation #152:	HelIo, wLrld!	0.8461538461538461
# Generation #153:	HelIo, wqrld!	0.8461538461538461
# Generation #154:	HelIo, wlrld!	0.8461538461538461
# Generation #155:	HelIo, wrrld!	0.8461538461538461
# Generation #156:	Hel,o, wrrld!	0.8461538461538461
# Generation #157:	Helpo, wrrld!	0.8461538461538461
# Generation #158:	Helpo, wurld!	0.8461538461538461
# Generation #159:	Helso, wurld!	0.8461538461538461
# Generation #160:	Helso, wzrld!	0.8461538461538461
# Generation #161:	HelLo, wzrld!	0.8461538461538461
# Generation #162:	HelLo, wzrle!	0.7692307692307693
# Generation #163:	HelLo, wbrle!	0.7692307692307693
# Generation #164:	HelLo, wErle!	0.7692307692307693
# Generation #165:	HelLo, wdrle!	0.7692307692307693
# Generation #166:	HelLo, wdrlu!	0.7692307692307693
# Generation #167:	HelLo, wdrlt!	0.7692307692307693
# Generation #168:	HelLo, w!rlt!	0.7692307692307693
# Generation #169:	HelLo, wErlt!	0.7692307692307693
# Generation #170:	HelGo, wErlt!	0.7692307692307693
# Generation #171:	HelGo, wGrlt!	0.7692307692307693
# Generation #172:	HelGo, wprlt!	0.7692307692307693
# Generation #173:	HelGo, wprlx!	0.7692307692307693
# Generation #174:	HelGo, wprlÑ!	0.7692307692307693
# Generation #175:	HelGo, wArlÑ!	0.7692307692307693
# Generation #176:	Hel¡o, wArlÑ!	0.7692307692307693
# Generation #177:	Hel¡o, worlÑ!	0.8461538461538461
# Generation #178:	Hel¡o, worlÑ!	0.8461538461538461
# Generation #179:	Hel¡o, worl.!	0.8461538461538461
# Generation #180:	Heljo, worl.!	0.8461538461538461
# Generation #181:	Heljo, worlñ!	0.8461538461538461
# Generation #182:	Heljo, worlF!	0.8461538461538461
# Generation #183:	HelDo, worlF!	0.8461538461538461
# Generation #184:	HelDo, worlF!	0.8461538461538461
# Generation #185:	HelDo, worlQ!	0.8461538461538461
# Generation #186:	HelDo, worls!	0.8461538461538461
# Generation #187:	HelDo, worlA!	0.8461538461538461
# Generation #188:	HelLo, worlA!	0.8461538461538461
# Generation #189:	HelLo, worlA!	0.8461538461538461
# Generation #190:	HelLo, worlñ!	0.8461538461538461
# Generation #191:	HelIo, worlñ!	0.8461538461538461
# Generation #192:	HelIo, worlW!	0.8461538461538461
# Generation #193:	HelIo, worla!	0.8461538461538461
# Generation #194:	HelIo, worla!	0.8461538461538461
# Generation #195:	HelIo, worlG!	0.8461538461538461
# Generation #196:	HelIo, worlw!	0.8461538461538461
# Generation #197:	Helho, worlw!	0.8461538461538461
# Generation #198:	HelHo, worlw!	0.8461538461538461
# Generation #199:	HelHo, worlN!	0.8461538461538461
# Generation #200:	HelHo, worlk!	0.8461538461538461
# Generation #201:	HelHo, worlg!	0.8461538461538461
# Generation #202:	HelHo, worlg!	0.8461538461538461
# Generation #203:	HelHo, worlF!	0.8461538461538461
# Generation #204:	HelHo, worlp!	0.8461538461538461
# Generation #205:	HelGo, worlp!	0.8461538461538461
# Generation #206:	Hel¡o, worlp!	0.8461538461538461
# Generation #207:	Hel¡o, worlp!	0.8461538461538461
# Generation #208:	HelUo, worlp!	0.8461538461538461
# Generation #209:	Helwo, worlp!	0.8461538461538461
# Generation #210:	Helho, worlp!	0.8461538461538461
# Generation #211:	Helho, worlw!	0.8461538461538461
# Generation #212:	Helho, worli!	0.8461538461538461
# Generation #213:	Helho, worli!	0.8461538461538461
# Generation #214:	Heluo, worli!	0.8461538461538461
# Generation #215:	HelMo, worli!	0.8461538461538461
# Generation #216:	HelMo, worlH!	0.8461538461538461
# Generation #217:	HelYo, worlH!	0.8461538461538461
# Generation #218:	HelYo, worlp!	0.8461538461538461
# Generation #219:	Hello, worlp!	0.9230769230769231
# Generation #220:	Hello, worlM!	0.9230769230769231
# Generation #221:	Hello, worlP!	0.9230769230769231
# Generation #222:	Hello, worlp!	0.9230769230769231
# Generation #223:	Hello, worlc!	0.9230769230769231
# Generation #224:	Hello, worlñ!	0.9230769230769231
# Generation #225:	Hello, worlñ!	0.9230769230769231
# Generation #226:	Hello, worlL!	0.9230769230769231
# Generation #227:	Helloj worlL!	0.8461538461538461
# Generation #228:	Helloj worle!	0.8461538461538461
# Generation #229:	Helloq worle!	0.8461538461538461
# Generation #230:	HelloD worle!	0.8461538461538461
# Generation #231:	Hellok worle!	0.8461538461538461
# Generation #232:	HelloK worle!	0.8461538461538461
# Generation #233:	HelloW worle!	0.8461538461538461
# Generation #234:	HelloI worle!	0.8461538461538461
# Generation #235:	HelloZ worle!	0.8461538461538461
# Generation #236:	HelloZ worlx!	0.8461538461538461
# Generation #237:	Hellog worlx!	0.8461538461538461
# Generation #238:	HelloB worlx!	0.8461538461538461
# Generation #239:	Hellog worlx!	0.8461538461538461
# Generation #240:	Helloy worlx!	0.8461538461538461
# Generation #241:	Helloy world!	0.9230769230769231
# Generation #242:	HelloK world!	0.9230769230769231
# Generation #243:	HellUK world!	0.8461538461538461
# Generation #244:	HellUq world!	0.8461538461538461
# Generation #245:	HellUK world!	0.8461538461538461
# Generation #246:	HellUK world!	0.8461538461538461
# Generation #247:	HelltK world!	0.8461538461538461
# Generation #248:	HellEK world!	0.8461538461538461
# Generation #249:	HellWK world!	0.8461538461538461
# Generation #250:	HellwK world!	0.8461538461538461
# Generation #251:	HellcK world!	0.8461538461538461
# Generation #252:	HellPK world!	0.8461538461538461
# Generation #253:	HellPz world!	0.8461538461538461
# Generation #254:	HellPW world!	0.8461538461538461
# Generation #255:	HellPW world!	0.8461538461538461
# Generation #256:	HellPC world!	0.8461538461538461
# Generation #257:	HellhC world!	0.8461538461538461
# Generation #258:	HelloC world!	0.9230769230769231
# Generation #259:	Helloq world!	0.9230769230769231
# Generation #260:	Helloq world!	0.9230769230769231
# Hello, world! 1.0
